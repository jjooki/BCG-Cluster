# %% [markdown]
# # SDSS dr13 Skyserver SQL Crawler
# ## SQL examples
# ```SQL
# -- This query does a table JOIN between the imaging (PhotoObj) and spectra
# -- (SpecObj) table includes the necessary columns in the SELECT to upload
# -- (dbo.fGetNearbyObjEq) function finds nearby object ra-dec coordinates within [ra - theta, ra + theta] and [dec - theta, dec + theta]
# -- magnitude = petroMag - extinction for each ugriz filters
# --
#
#
# SELECT
#    p.objid, p.ra, p.dec, p.l, p.b,
#    p.petroMag_u-p.extinction_u AS mag_u,
#    p.petroMag_g-p.extinction_g AS mag_g,
#    p.petroMag_r-p.extinction_r AS mag_r,
#    p.petroMag_i-p.extinction_i AS mag_i,
#    p.petroMag_z-p.extinction_z AS mag_z,
#    s.z as redshift, s.zErr as redshift_err,
#    s.velDisp, s.velDispErr,
#    passive.logmass as passive_logmass,
#    ROUND(pca.mstellar_median, 2) as pca_logmass,
#    ROUND(passive.logmass-passive.minlogmass, 3) as logmass_lowerErr,
#    ROUND(passive.maxlogmass-passive.logmass, 3) as logmass_upperErr,
#    passive.absMagK,
#    pca.vdisp_median as pca_vdisp, pca.vdisp_err as pca_vdisp_err,
#    zoo.p_el_debiased as frac_ellip,
#    zoo.p_cs_debiased as frac_spiral
# FROM Galaxy AS p
#    JOIN dbo.fGetNearbyObjEq({ra}, {dec}, {theta}) AS GN ON GN.objid = p.objid
#    JOIN SpecObj AS s ON s.bestobjid = p.objid
#    LEFT JOIN stellarMassPassivePort AS passive ON passive.specobjid = s.specobjid
#    LEFT JOIN stellarMassPCAWiscM11 AS pca ON pca.specobjid = s.specobjid
#    LEFT JOIN zooSpec AS zoo ON zoo.specobjid = s.specobjid
# WHERE
#    s.class = 'GALAXY'
#    AND s.z BETWEEN {z_lower} AND {z_upper}
# ```

# %% [markdown]
# ### Sitemap
# - [SDSS dr13 Skyserver Schema Browser](http://skyserver.sdss.org/dr13/en/help/browser/browser.aspx)
# - [SQL Search](http://skyserver.sdss.org/dr13/en/tools/search/sql.aspx)

# %% [markdown]
# ## Crawling data description
#
# |Column|Description|Unit|
# |------|-----------|----|
# |objid|Object number in SDSS|-|
# |ra|Right Ascension|deg|
# |dec|Declination|deg|
# |l|galactic longitude|deg|
# |b|galactic latitude|deg|
# |mag_u|Petrosian u-band magnitude corrected for extinction|mag|
# |mag_g|Petrosian g-band magnitude corrected for extinction|mag|
# |mag_r|Petrosian r-band magnitude corrected for extinction|mag|
# |mag_i|Petrosian i-band magnitude corrected for extinction|mag|
# |mag_z|Petrosian z-band magnitude corrected for extinction|mag|
# |z|Redshift corresponds to no-QSO redshift|-|
# |zErr|Redshift error|-|
# |velDisp|Velocity dispersion|km/s|
# |velDispErr|Velocity dispersion error|km/s|
# |passive_logmass|$logM$|$logM_{\odot}$|
# |pca_logmass|$logM$ measured by pca method|$logM_{\odot}$|
# |logmass_lowerErr|pca_logmass lower error|$logM_{\odot}$|
# |logmass_upperErr|pca_logmass upper error|$logM_{\odot}$|
# |absMagK|Absolute magnitude in K inferred from model|mag|
# |pca_vdisp|PCA Velocity dispersion|km/s|
# |pca_vdisp_err|PCA Velocity dispersion Error|km/s|
# |frac_ellip|debiased fraction of votes for elliptical|-|
# |frac_spiral|debiased fraction of votes for spiral|-|

# %% [markdown]
# ## GalWCat19 cluster data description
#
# |Column|Description|Unit|
# |------|-----------|----|
# |  Ng   |Number of total galaxy members for this cluster|-|
# | ClID  |           Cluster Identifier        |-|
# |RAJ2000|Cluster center right ascension(J2000)|deg|
# |DEJ2000|Cluster center right ascension(J2000)|deg|
# |   z   |Redshift corresponds to no-QSO redshift|-|
# |   RV  |      Cluster radial velocity        |$km/s$|
# |CoDist |          Comoving distance          |$h^{-1}Mpc$|
# |  r500 |Radius from the cluster center at which $\rho=\Delta_{500}\rho_{c}$|$h^{-1}Mpc$|
# |  N500 |Number of all member galaxies within r500|-|
# |sig500 |Velocity dispersion within r500|km/s|
# | M500  |Cluster mass within r500|$M_{\odot}$|
# | r200  |Radius from the cluster center at which $\rho=\Delta_{200}\rho_{c}$|$h^{-1}Mpc$|
# | N200  |Number of all member galaxies within r200|-|
# | sig200|Velocity dispersion within r200|km/s|
# | M200  |Cluster mass within r200|$M_{\odot}$|
# | r100  |Radius from the cluster center at which $\rho=\Delta_{100}\rho_{c}$|$h^{-1}Mpc$|
# | N100  |Number of all member galaxies within r100|-|
# | sig100|Velocity dispersion within r100|km/s|
# | M100  |Cluster mass within r100|$M_{\odot}$|
# | r005  |Radius from the cluster center at which $\rho=\Delta_{005}\rho_{c}$|$h^{-1}Mpc$|
# | N005  |Number of all member galaxies within r005|-|
# | sig005|   Velocity dispersion within r005  |km/s|
# | M005  |      Cluster mass within r005      |$M_{\odot}$|
# |  Rs   |           NFW scale radius         |$h^{-1}Mpc$|
# |  Ms   |            NFW scale mass          |$M_{\odot}$|
# | conc  |    Concentration = $R_{200}/R_s$   |-|

# %% [markdown]
# ## GalWCat19 galaxy members data description
#
# |Column|Description|Unit|
# |------|-----------|----|
# |RAJ2000|Cluster center right ascension(J2000)|deg|
# |DEJ2000|Cluster center right ascension(J2000)|deg|
# |z|Redshift corresponds to no-QSO redshift|-|
# |ClID|Cluster Identifier|-|

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import scipy.integrate as integrate

import warnings
warnings.filterwarnings(action='ignore')

import time
import math
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import os

c = 299792.458
sign = 8
multiple = 6
rad2deg = 180 / np.pi

# %%
def set_chrome_driver():
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument('headless')
    driver = webdriver.Chrome(executable_path="../chromedriver",
                              options=chrome_options)
    return driver

# %%
def make_query(ra, dec, theta, r200, dist, z_upper, z_lower):
    query = f"""SELECT
   p.objid, p.ra, p.dec, p.l, p.b,
   p.petroMag_u-p.extinction_u AS mag_u,
   p.petroMag_g-p.extinction_g AS mag_g,
   p.petroMag_r-p.extinction_r AS mag_r,
   p.petroMag_i-p.extinction_i AS mag_i,
   p.petroMag_z-p.extinction_z AS mag_z,
   s.z, s.zErr, s.velDisp, s.velDispErr,
   passive.logmass as passive_logmass,
   ROUND(pca.mstellar_median, 2) as pca_logmass,
   ROUND(passive.logmass-passive.minlogmass, 3) as logmass_lowerErr,
   ROUND(passive.maxlogmass-passive.logmass, 3) as logmass_upperErr,
   passive.absMagK,
   pca.vdisp_median as pca_vdisp, pca.vdisp_err as pca_vdisp_err,
   zoo.p_el_debiased as frac_ellip,
   zoo.p_cs_debiased as frac_spiral
FROM Galaxy AS p
   JOIN dbo.fGetNearbyObjEq({ra}, {dec}, {theta}) AS GN ON GN.objid = p.objid
   JOIN SpecObj AS s ON s.bestobjid = p.objid
   LEFT JOIN stellarMassPassivePort AS passive ON passive.specobjid = s.specobjid
   LEFT JOIN stellarMassPCAWiscM11 AS pca ON pca.specobjid = s.specobjid
   LEFT JOIN zooSpec AS zoo ON zoo.specobjid = s.specobjid
WHERE
   s.class = 'GALAXY'
   AND s.z BETWEEN {z_lower} AND {z_upper}"""
    return query

# %%
def get_csv(driver, query):
    driver.find_element(By.XPATH, '//*[@id="clear"]').click()
    driver.find_element(By.XPATH, '//*[@id="cmd"]').send_keys(query)
    driver.find_element(By.XPATH, '//*[@id="transp"]/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td[4]/input').click()
    driver.find_element(By.XPATH, '/html/body/div[4]/form/table/tbody/tr[3]/td/table/tbody/tr/td[1]/table/tbody/tr[6]/td/input').click()
    
    time.sleep(np.random.randint(20,30))

# %%
def digitScaler(num, sign):
    digit = math.floor(np.log10(num))
    n = num / 10**digit
    n = round(n, sign-1)
    return n * math.pow(10,digit)

def redshift(v_r):
    # calculating relativistic redshift with radial velocity
    return np.sqrt((c + v_r)/(c - v_r)) - 1

def radial_v(z):
    # calculating relativistic radial velocity with redshift
    return c * ((z+1)**2 - 1)/((z+1)**2 + 1)

def dimless_h(z, h_0=1):
    # Calculating dimesionless hubble constant, h(z)
    # According to the GalWCat19 paper,
    # Omega(r, m, k, gamma) = (0, 0.3, 0, 0.7)
    # h_0 = 0.7
    return h_0 * np.sqrt(0.3*(1+z)**3 + 0.7)

def comv_dist(z):
    return (c / 100) * integrate.quad(lambda x: 1/dimless_h(x), 0, z)[0]

def angular_dist(delta_ra, delta_dec):
    tr = np.pi / 180
    return np.arccos(np.cos(delta_ra * tr) * np.cos(delta_dec * tr)) / tr

# %%
header = ['ra', 'dec', 'z', 'v_r',
          'comv_dist', 'r_200', 'N_200', 'sigma_200',
          'sigma_200_lowerErr', 'sigma_200_upperErr', 'M_200', 'M_200_Err',
          'R_s', 'R_s_Err', 'M_s', 'M_s_Err']
cls_info = pd.read_csv('./data/GalWCls19_summary.csv',index_col=0)
cls_info.columns = header
cls_info
# Out:
#              ra        dec         z         v_r   comv_dist     r_200  N_200  \
# ID
# 1     230.65973  27.743846  0.073177  21137.1930  215.714310  1.758845    167
# 2     227.55402  33.498096  0.113908  32215.0730  332.547940  1.511349     63
# 3     194.93502  27.912461  0.023372   6924.9620   69.697942  1.544850    672
# 4     258.20851  64.052953  0.080997  23301.8680  238.327350  1.453410    155
# 5     209.83093  27.968947  0.075065  21661.5240  221.182270  1.448992     77
# ...         ...        ...       ...         ...         ...       ...    ...
# 996   124.92122  21.032812  0.093382  26693.3160  273.964500  0.689068     10
# 997   134.80258  39.671084  0.027620   8165.9917   82.285446  0.703441     12
# 998   164.50680   1.634841  0.039362  11568.5010  116.952150  0.700718     51
# 999   149.25617  26.150842  0.081776  23516.6380  240.576530  0.691300     11
# 1000  193.01306   4.574587  0.065021  18860.4310  192.040150  0.694710     27
#
#        sigma_200  sigma_200_lowerErr  sigma_200_upperErr         M_200  \
# ID
# 1     1042.08600          -83.233978          100.849290  1.350000e+15
# 2      926.75761          -92.042355          118.740250  8.950000e+14
# 3      932.60305          -47.761507           55.312723  8.760000e+14
# 4      881.24884          -70.222098           82.083225  7.700000e+14
# 5      842.65332          -83.231049           96.160155  7.590000e+14
# ...          ...                 ...                 ...           ...
# 996    387.83579          -76.069234          103.545850  8.310000e+13
# 997    449.75002         -251.333430          196.605620  8.300000e+13
# 998    421.30468          -72.371673          106.786410  8.290000e+13
# 999    383.44056         -142.616450          204.362490  8.290000e+13
# 1000   388.88911          -65.828151           97.173264  8.280000e+13
#
#          M_200_Err   R_s  R_s_Err           M_s       M_s_Err
# ID
# 1     3.570000e+14  0.41    0.108  3.060000e+14  8.060000e+13
# 2     2.350000e+14  0.32    0.084  1.880000e+14  4.930000e+13
# 3     2.230000e+14  0.33    0.084  1.850000e+14  4.710000e+13
# 4     2.080000e+14  0.37    0.100  1.860000e+14  5.040000e+13
# 5     2.170000e+14  0.14    0.040  9.660000e+13  2.760000e+13
# ...            ...   ...      ...           ...           ...
# 996   4.650000e+13  0.05    0.028  9.110000e+12  5.100000e+12
# 997   3.320000e+13  0.04    0.016  8.110000e+12  3.240000e+12
# 998   2.330000e+13  0.37    0.104  3.930000e+13  1.100000e+13
# 999   2.950000e+13  0.09    0.032  1.260000e+13  4.460000e+12
# 1000  3.110000e+13  0.16    0.060  1.850000e+13  6.950000e+12
#
# [1000 rows x 16 columns]

# %%
cls1 = cls_info.iloc[0,:]

v = cls1['v_r']
z_calc = redshift(v)
v_calc = radial_v(cls1['z'])
print(digitScaler(v_calc, sign))
print(v)
print(cls1['comv_dist'])
print(digitScaler(comv_dist(cls1['z']), sign))
# Out:
# 21137.193
# 21137.193
# 215.71431
# 215.71430999999998

# %%
print(digitScaler(angular_dist(1, 1), sign_fig))
# Out:
# 1.4141777
# 1.4142135623730951

# %%
idx = 16
ra = cls_info.loc[idx, 'ra']
dec = cls_info.loc[idx, 'dec']
dist = cls_info.loc[idx, 'comv_dist']
r200 = cls_info.loc[idx, 'r_200']
v_r = cls_info.loc[idx, 'v_rad']
sigma = cls_info.loc[idx, 'sigma_200']

z_upper = redshift(v_r + multiple * sigma)
z_lower = redshift(v_r - multiple * sigma)

query = make_query(ra, dec, r200, dist, z_upper, z_lower)
print(query)
# Out:
# SELECT
#    p.objid, p.ra, p.dec, p.l, p.b,
#    p.petroMag_u-p.extinction_u AS mag_u,
#    p.petroMag_g-p.extinction_g AS mag_g,
#    p.petroMag_r-p.extinction_r AS mag_r,
#    p.petroMag_i-p.extinction_i AS mag_i,
#    p.petroMag_z-p.extinction_z AS mag_z,
#    s.z, s.zErr, s.velDisp, s.velDispErr,
#    passive.logmass as passive_logmass,
#    ROUND(pca.mstellar_median, 2) as pca_logmass,
#    ROUND(passive.logmass-passive.minlogmass, 3) as logmass_lowerErr,
#    ROUND(passive.maxlogmass-passive.logmass, 3) as logmass_upperErr,
#    passive.absMagK,
#    pca.vdisp_median as pca_vdisp, pca.vdisp_err as pca_vdisp_err,
#    zoo.p_el_debiased as frac_ellip,
#    zoo.p_cs_debiased as frac_spiral
# FROM Galaxy AS p
#    JOIN dbo.fGetNearbyObjEq(10.400877, -9.3250982, 1.6301228566004442) AS GN ON GN.objid = p.objid
#    JOIN SpecObj AS s ON s.bestobjid = p.objid
#    LEFT JOIN stellarMassPassivePort AS passive ON passive.specobjid = s.specobjid
#    LEFT JOIN stellarMassPCAWiscM11 AS pca ON pca.specobjid = s.specobjid
#    LEFT JOIN zooSpec AS zoo ON zoo.specobjid = s.specobjid
# WHERE
#    s.class = 'GALAXY'
#    AND s.z BETWEEN -0.014026752340765225 AND 0.015338868606316058

# %%
url = "http://skyserver.sdss.org/dr13/en/tools/search/sql.aspx"
driver = set_chrome_driver()
driver.get(url)

driver.find_element(By.XPATH, '//*[@id="clear"]').click()
driver.find_element(By.XPATH, '//*[@id="cmd"]').send_keys(query)
driver.find_element(By.XPATH, '//*[@id="transp"]/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td[4]/input').click()
driver.find_element(By.XPATH, '/html/body/div[4]/form/table/tbody/tr[3]/td/table/tbody/tr/td[1]/table/tbody/tr[6]/td/input').click()

time.sleep(3)
first_tab = driver.window_handles[0]
driver.switch_to.window(window_name=first_tab)

# for idx, cls1 in cls_info.iloc[1000:,:].iterrows():
#     ra = cls1['ra']
#     dec = cls1['dec']
#     dist = cls1['comv_dist']
#     r200 = cls1['r_200']
#     v_r = cls1['v_rad']
#     sigma = cls1['sigma_200']
    
#     z_upper = redshift(v_r + multiple * sigma)
#     z_lower = redshift(v_r - multiple * sigma)
    
#     query = make_query(ra, dec, r200, dist, z_upper, z_lower)
# #     get_html(driver, query)
#     get_csv(driver, query)
    
# #     if idx > 0:
# #         break

# %% [markdown]
# ### solution method with delay issues

# %%
def get_missing_data(driver, cls_info, index, multiple):
    ra = cls1['ra']
    dec = cls1['dec']
    dist = cls1['comv_dist']
    r200 = cls1['r_200']
    v_r = cls1['v_rad']
    sigma = cls1['sigma_200']
    theta = multiple * np.arcsin(r200 / dist) * (180 / np.pi) * 60
    print('Index: {0} & process: {1:.2f}%'.format(idx, 100 * idx/N))
    
    z_upper = redshift(v_r + multiple * sigma)
    z_lower = redshift(v_r - multiple * sigma)
    
    query = make_query(ra, dec, theta, r200, dist, z_upper, z_lower)
    get_csv(driver, query)

# %%
get_missing_data(1201)

# %% [markdown]
# ## GalWgal another properties crawler

# %%
header = ['N_gal', 'ra', 'dec',
          'z', 'v_rad', 'comv_dist',
          'r_500', 'N_500', 'sigma_500', 'M_500',
          'r_200', 'N_200', 'sigma_200', 'M_200',
          'r_100', 'N_100', 'sigma_100', 'M_100',
          'r_005', 'N_005', 'sigma_005', 'M_005',
          'R_s', 'M_s', 'concentration']

cls_info = pd.read_csv('./data/galwcls.csv', index_col=0)
cls_info = cls_info.reset_index()
cls_info = cls_info.drop(columns=['ClID'])
cls_info.index = cls_info.index + 1
cls_info.columns = header
cls_info.iloc[:1000, :]
# Out:
#       N_gal         ra        dec         z       v_rad   comv_dist     r_500  \
# 1       166  230.65973  27.743846  0.073177  21137.1930  215.714310  1.151608
# 2        61  227.55402  33.498096  0.113908  32215.0730  332.547940  0.995621
# 3       670  194.93502  27.912461  0.023372   6924.9620   69.697942  1.017135
# 4       149  258.20851  64.052953  0.080997  23301.8680  238.327350  0.945980
# 5        75  209.83093  27.968947  0.075065  21661.5240  221.182270  0.990827
# ...     ...        ...        ...       ...         ...         ...       ...
# 996      10  124.92122  21.032812  0.093382  26693.3160  273.964500  0.475609
# 997      12  134.80258  39.671084  0.027620   8165.9917   82.285446  0.488771
# 998      51  164.50680   1.634841  0.039362  11568.5010  116.952150  0.427736
# 999      11  149.25617  26.150842  0.081776  23516.6380  240.576530  0.467134
# 1000     27  193.01306   4.574587  0.065021  18860.4310  192.040150  0.455221
#
#       N_500   sigma_500         M_500  ...  N_100  sigma_100         M_100  \
# 1       123  1132.33920  9.506491e+14  ...    191  991.86324  1.689758e+15
# 2        45  1007.64840  6.394636e+14  ...     76  873.68274  1.104408e+15
# 3       485   992.56078  6.248669e+14  ...    801  897.76898  1.081975e+15
# 4       103   863.31423  5.309468e+14  ...    183  838.62740  9.705232e+14
# 5        56   858.50327  6.065896e+14  ...     91  817.41602  8.778047e+14
# ...     ...         ...           ...  ...    ...        ...           ...
# 996      10   387.83579  6.830086e+13  ...     10  387.83579  9.451712e+13
# 997       8   537.94560  6.961029e+13  ...     13  437.73512  9.329420e+13
# 998      25   367.68276  4.716706e+13  ...     71  392.67168  1.164570e+14
# 999       8   419.10904  6.398235e+13  ...     13  355.75066  9.797732e+13
# 1000     19   409.60851  5.825840e+13  ...     32  375.01613  1.031698e+14
#
#          r_005  N_005  sigma_005         M_005   R_s           M_s  \
# 1     7.794941    446  706.55424  3.242931e+15  0.41  3.060947e+14
# 2     6.618137    143  695.01505  2.066015e+15  0.32  1.879991e+14
# 3     6.772127   1389  750.50479  2.028706e+15  0.33  1.852209e+14
# 4     6.516373    314  683.99230  1.909044e+15  0.37  1.864585e+14
# 5     5.876928    189  632.52100  1.392339e+15  0.14  9.659857e+13
# ...        ...    ...        ...           ...   ...           ...
# 996   2.738279     12  356.41517  1.433846e+14  0.05  9.112707e+12
# 997   2.753838     32  297.94465  1.369509e+14  0.04  8.112498e+12
# 998   3.545243    145  315.50320  2.954213e+14  0.37  3.925326e+13
# 999   2.875196     46  469.10444  1.641084e+14  0.09  1.255210e+13
# 1000  3.074107     50  307.67353  1.973513e+14  0.16  1.854155e+13
#
#       concentration
# 1          4.289865
# 2          4.722965
# 3          4.681364
# 4          3.928135
# 5         10.349945
# ...             ...
# 996       13.781365
# 997       17.586027
# 998        1.893833
# 999        7.681110
# 1000       4.341937
#
# [1000 rows x 25 columns]

# %%
def make_query(ra, dec, theta, r200, dist, z_upper, z_lower):
    query = f"""SELECT
   p.objid, p.ra, p.dec, p.l, p.b,
   p.petroMag_u-p.extinction_u AS mag_u,
   p.petroMag_g-p.extinction_g AS mag_g,
   p.petroMag_r-p.extinction_r AS mag_r,
   p.petroMag_i-p.extinction_i AS mag_i,
   p.petroMag_z-p.extinction_z AS mag_z,
   s.z, s.zErr, s.velDisp, s.velDispErr,
   passive.logmass as passive_logmass,
   ROUND(pca.mstellar_median, 2) as pca_logmass,
   ROUND(passive.logmass-passive.minlogmass, 3) as logmass_lowerErr,
   ROUND(passive.maxlogmass-passive.logmass, 3) as logmass_upperErr,
   passive.absMagK,
   pca.vdisp_median as pca_vdisp, pca.vdisp_err as pca_vdisp_err,
   zoo.p_el_debiased as frac_ellip,
   zoo.p_cs_debiased as frac_spiral
FROM Galaxy AS p
   JOIN dbo.fGetNearbyObjEq({ra}, {dec}, {theta}) AS GN ON GN.objid = p.objid
   JOIN SpecObj AS s ON s.bestobjid = p.objid
   LEFT JOIN stellarMassPassivePort AS passive ON passive.specobjid = s.specobjid
   LEFT JOIN stellarMassPCAWiscM11 AS pca ON pca.specobjid = s.specobjid
   LEFT JOIN zooSpec AS zoo ON zoo.specobjid = s.specobjid
WHERE
   s.class = 'GALAXY'
   AND s.z BETWEEN {z_lower} AND {z_upper}"""
    return query

# %%
def remove_cachefile(listdir):
    try:
        ld = listdir.remove('.DS_store')
    except:
        ld = listdir
    return ld

def wait_download(path):
    count = len(remove_cachefile(os.listdir(path)))
    while True:
        pre_count = count
        time.sleep(5)
        count = len(remove_cachefile(os.listdir(path)))
        if count > pre_count:
            break
            
def get_csv(driver, query):
    driver.find_element(By.XPATH, '//*[@id="clear"]').click()
    driver.find_element(By.XPATH, '//*[@id="cmd"]').send_keys(query)
    driver.find_element(By.XPATH, '//*[@id="transp"]/form/table/tbody/tr[3]/td/table/tbody/tr/td[2]/table/tbody/tr[1]/td[4]/input').click()
    driver.find_element(By.XPATH, '/html/body/div[4]/form/table/tbody/tr[3]/td/table/tbody/tr/td[1]/table/tbody/tr[6]/td/input').click()
    wait_download('./')

def get_html(driver, query):
    driver.find_element(By.XPATH, '//*[@id="clear"]').click()
    driver.find_element(By.XPATH, '//*[@id="cmd"]').send_keys(query)
    driver.find_element(By.XPATH, '/html/body/div[4]/form/table/tbody/tr[3]/td/table/tbody/tr/td[1]/table/tbody/tr[6]/td/input').click()
    
    time.sleep(np.random.randint(3,5))
    first_tab = driver.window_handles[0]
    driver.switch_to.window(window_name=first_tab)

# %%
url = "http://skyserver.sdss.org/dr13/en/tools/search/sql.aspx"
driver = set_chrome_driver()
driver.get(url)
N = len(cls_info)

for idx, cls1 in cls_info.loc[621:, :].iterrows():
    ra = cls1['ra']
    dec = cls1['dec']
    dist = cls1['comv_dist']
    r200 = cls1['r_200']
    v_r = cls1['v_rad']
    sigma = cls1['sigma_200']
    theta = multiple * np.arcsin(r200 / dist) * (180 / np.pi) * 60
    print('Index: {0} & process: {1:.2f}%'.format(idx, 100 * idx/N))
    
    z_upper = redshift(v_r + multiple * sigma)
    z_lower = redshift(v_r - multiple * sigma)
    
    query = make_query(ra, dec, theta, r200, dist, z_upper, z_lower)
    get_csv(driver, query)
    
#     if idx > 0:
#         break
# Out:
# Index: 621 & process: 34.50%
# Index: 622 & process: 34.56%
# Index: 623 & process: 34.61%
# Index: 624 & process: 34.67%
# Index: 625 & process: 34.72%
# Index: 626 & process: 34.78%
# Index: 627 & process: 34.83%
# Index: 628 & process: 34.89%
# Index: 629 & process: 34.94%
# Index: 630 & process: 35.00%
# Index: 631 & process: 35.06%
# Index: 632 & process: 35.11%
# Index: 633 & process: 35.17%
# Index: 634 & process: 35.22%
# Index: 635 & process: 35.28%
# Index: 636 & process: 35.33%
# Index: 637 & process: 35.39%
# Index: 638 & process: 35.44%
# Index: 639 & process: 35.50%
# Index: 640 & process: 35.56%
# Index: 641 & process: 35.61%
# Index: 642 & process: 35.67%
# Index: 643 & process: 35.72%
# Index: 644 & process: 35.78%
# Index: 645 & process: 35.83%
# Index: 646 & process: 35.89%
# Index: 647 & process: 35.94%
# Index: 648 & process: 36.00%
# Index: 649 & process: 36.06%
# Index: 650 & process: 36.11%
# Index: 651 & process: 36.17%
# Index: 652 & process: 36.22%
# Index: 653 & process: 36.28%
# Index: 654 & process: 36.33%
# Index: 655 & process: 36.39%
# Index: 656 & process: 36.44%
# Index: 657 & process: 36.50%
# Index: 658 & process: 36.56%
# Index: 659 & process: 36.61%
# Index: 660 & process: 36.67%
# Index: 661 & process: 36.72%
# Index: 662 & process: 36.78%
# Index: 663 & process: 36.83%
# Index: 664 & process: 36.89%
# Index: 665 & process: 36.94%
# Index: 666 & process: 37.00%
# Index: 667 & process: 37.06%
# Index: 668 & process: 37.11%
# Index: 669 & process: 37.17%
# Index: 670 & process: 37.22%
# Index: 671 & process: 37.28%
# Index: 672 & process: 37.33%
# Index: 673 & process: 37.39%
# Index: 674 & process: 37.44%
# Index: 675 & process: 37.50%
# Index: 676 & process: 37.56%
# Index: 677 & process: 37.61%
# Index: 678 & process: 37.67%
# Index: 679 & process: 37.72%
# Index: 680 & process: 37.78%
# Index: 681 & process: 37.83%
# Index: 682 & process: 37.89%
# Index: 683 & process: 37.94%
# Index: 684 & process: 38.00%
# Index: 685 & process: 38.06%
# Index: 686 & process: 38.11%
# Index: 687 & process: 38.17%
# Index: 688 & process: 38.22%
# Index: 689 & process: 38.28%
# Index: 690 & process: 38.33%
# Index: 691 & process: 38.39%
# Index: 692 & process: 38.44%
# Index: 693 & process: 38.50%
# Index: 694 & process: 38.56%
# Index: 695 & process: 38.61%
# Index: 696 & process: 38.67%
# Index: 697 & process: 38.72%
# Index: 698 & process: 38.78%
# Index: 699 & process: 38.83%
# Index: 700 & process: 38.89%
# Index: 701 & process: 38.94%
# Index: 702 & process: 39.00%
# Index: 703 & process: 39.06%
# Index: 704 & process: 39.11%
# Index: 705 & process: 39.17%
# Index: 706 & process: 39.22%
# Index: 707 & process: 39.28%
# Index: 708 & process: 39.33%
# Index: 709 & process: 39.39%
# Index: 710 & process: 39.44%
# Index: 711 & process: 39.50%
# Index: 712 & process: 39.56%
# Index: 713 & process: 39.61%
# Index: 714 & process: 39.67%
# Index: 715 & process: 39.72%
# Index: 716 & process: 39.78%
# Index: 717 & process: 39.83%
# Index: 718 & process: 39.89%
# Index: 719 & process: 39.94%
# Index: 720 & process: 40.00%
# Index: 721 & process: 40.06%
# Index: 722 & process: 40.11%
# Index: 723 & process: 40.17%
# Index: 724 & process: 40.22%
# Index: 725 & process: 40.28%
# Index: 726 & process: 40.33%
# Index: 727 & process: 40.39%
# Index: 728 & process: 40.44%
# Index: 729 & process: 40.50%
# Index: 730 & process: 40.56%
# Index: 731 & process: 40.61%
# Index: 732 & process: 40.67%
# Index: 733 & process: 40.72%
# Index: 734 & process: 40.78%
# Index: 735 & process: 40.83%
# Index: 736 & process: 40.89%
# Index: 737 & process: 40.94%
# Index: 738 & process: 41.00%
# Index: 739 & process: 41.06%
# Index: 740 & process: 41.11%
# Index: 741 & process: 41.17%
# Index: 742 & process: 41.22%
# Index: 743 & process: 41.28%
# Index: 744 & process: 41.33%
# Index: 745 & process: 41.39%
# Index: 746 & process: 41.44%
# Index: 747 & process: 41.50%
# Index: 748 & process: 41.56%
# Index: 749 & process: 41.61%
# Index: 750 & process: 41.67%
# Index: 751 & process: 41.72%
# Index: 752 & process: 41.78%
# Index: 753 & process: 41.83%
# Index: 754 & process: 41.89%
# Index: 755 & process: 41.94%
# Index: 756 & process: 42.00%
# Index: 757 & process: 42.06%
# Index: 758 & process: 42.11%
# Index: 759 & process: 42.17%
# Index: 760 & process: 42.22%
# Index: 761 & process: 42.28%
# Index: 762 & process: 42.33%
# Index: 763 & process: 42.39%
# Index: 764 & process: 42.44%
# Index: 765 & process: 42.50%
# Index: 766 & process: 42.56%
# Index: 767 & process: 42.61%
# Index: 768 & process: 42.67%
# Index: 769 & process: 42.72%
# Index: 770 & process: 42.78%
# Index: 771 & process: 42.83%
# Index: 772 & process: 42.89%
# Index: 773 & process: 42.94%
# Index: 774 & process: 43.00%
# Index: 775 & process: 43.06%
# Index: 776 & process: 43.11%
# Index: 777 & process: 43.17%
# Index: 778 & process: 43.22%
# Index: 779 & process: 43.28%
# Index: 780 & process: 43.33%
# Index: 781 & process: 43.39%
# Index: 782 & process: 43.44%
# Index: 783 & process: 43.50%
# Index: 784 & process: 43.56%
# Index: 785 & process: 43.61%
# Index: 786 & process: 43.67%
# Index: 787 & process: 43.72%
# Index: 788 & process: 43.78%
# Index: 789 & process: 43.83%
# Index: 790 & process: 43.89%
# Index: 791 & process: 43.94%
# Index: 792 & process: 44.00%
# Index: 793 & process: 44.06%
# Index: 794 & process: 44.11%
# Index: 795 & process: 44.17%
# Index: 796 & process: 44.22%
# Index: 797 & process: 44.28%
# Index: 798 & process: 44.33%
# Index: 799 & process: 44.39%
# Index: 800 & process: 44.44%
# Index: 801 & process: 44.50%
# Index: 802 & process: 44.56%
# Index: 803 & process: 44.61%
# Index: 804 & process: 44.67%
# Index: 805 & process: 44.72%
# Index: 806 & process: 44.78%
# Index: 807 & process: 44.83%
# Index: 808 & process: 44.89%
# Index: 809 & process: 44.94%
# Index: 810 & process: 45.00%
# Index: 811 & process: 45.06%
# Index: 812 & process: 45.11%
# Index: 813 & process: 45.17%
# Index: 814 & process: 45.22%
# Index: 815 & process: 45.28%
# Index: 816 & process: 45.33%
# Index: 817 & process: 45.39%
# Index: 818 & process: 45.44%
# Index: 819 & process: 45.50%
# Index: 820 & process: 45.56%
# Index: 821 & process: 45.61%
# Index: 822 & process: 45.67%
# Index: 823 & process: 45.72%
# Index: 824 & process: 45.78%
# Index: 825 & process: 45.83%
# Index: 826 & process: 45.89%
# Index: 827 & process: 45.94%
# Index: 828 & process: 46.00%
# Index: 829 & process: 46.06%
# Index: 830 & process: 46.11%
# Index: 831 & process: 46.17%
# Index: 832 & process: 46.22%
# Index: 833 & process: 46.28%
# Index: 834 & process: 46.33%
# Index: 835 & process: 46.39%
# Index: 836 & process: 46.44%
# Index: 837 & process: 46.50%
# Index: 838 & process: 46.56%
# Index: 839 & process: 46.61%
# Index: 840 & process: 46.67%
# Index: 841 & process: 46.72%
# Index: 842 & process: 46.78%
# Index: 843 & process: 46.83%
# Index: 844 & process: 46.89%
# Index: 845 & process: 46.94%
# Index: 846 & process: 47.00%
# Index: 847 & process: 47.06%
# Index: 848 & process: 47.11%
# Index: 849 & process: 47.17%
# Index: 850 & process: 47.22%
# Index: 851 & process: 47.28%
# Index: 852 & process: 47.33%
# Index: 853 & process: 47.39%
# Index: 854 & process: 47.44%
# Index: 855 & process: 47.50%
# Index: 856 & process: 47.56%
# Index: 857 & process: 47.61%
# Index: 858 & process: 47.67%
# Index: 859 & process: 47.72%
# Index: 860 & process: 47.78%
# Index: 861 & process: 47.83%
# Index: 862 & process: 47.89%
# Index: 863 & process: 47.94%
# Index: 864 & process: 48.00%
# Index: 865 & process: 48.06%
# Index: 866 & process: 48.11%
# Index: 867 & process: 48.17%
# Index: 868 & process: 48.22%
# Index: 869 & process: 48.28%
# Index: 870 & process: 48.33%
# Index: 871 & process: 48.39%
# Index: 872 & process: 48.44%
# Index: 873 & process: 48.50%
# Index: 874 & process: 48.56%
# Index: 875 & process: 48.61%
# Index: 876 & process: 48.67%
# Index: 877 & process: 48.72%
# Index: 878 & process: 48.78%
# Index: 879 & process: 48.83%
# Index: 880 & process: 48.89%
# Index: 881 & process: 48.94%
# Index: 882 & process: 49.00%
# Index: 883 & process: 49.06%
# Index: 884 & process: 49.11%
# Index: 885 & process: 49.17%
# Index: 886 & process: 49.22%
# Index: 887 & process: 49.28%
# Index: 888 & process: 49.33%
# Index: 889 & process: 49.39%
# Index: 890 & process: 49.44%
# Index: 891 & process: 49.50%
# Index: 892 & process: 49.56%
# Index: 893 & process: 49.61%
# Index: 894 & process: 49.67%
# Index: 895 & process: 49.72%
# Index: 896 & process: 49.78%
# Index: 897 & process: 49.83%
# Index: 898 & process: 49.89%
# Index: 899 & process: 49.94%
# Index: 900 & process: 50.00%
# Index: 901 & process: 50.06%
# Index: 902 & process: 50.11%
# Index: 903 & process: 50.17%
# Index: 904 & process: 50.22%
# Index: 905 & process: 50.28%
# Index: 906 & process: 50.33%
# Index: 907 & process: 50.39%
# Index: 908 & process: 50.44%
# Index: 909 & process: 50.50%
# Index: 910 & process: 50.56%
# Index: 911 & process: 50.61%
# Index: 912 & process: 50.67%
# Index: 913 & process: 50.72%
# Index: 914 & process: 50.78%
# Index: 915 & process: 50.83%
# Index: 916 & process: 50.89%
# Index: 917 & process: 50.94%
# Index: 918 & process: 51.00%
# Index: 919 & process: 51.06%
# Index: 920 & process: 51.11%
# Index: 921 & process: 51.17%
# Index: 922 & process: 51.22%
# Index: 923 & process: 51.28%
# Index: 924 & process: 51.33%
# Index: 925 & process: 51.39%
# Index: 926 & process: 51.44%
# Index: 927 & process: 51.50%
# Index: 928 & process: 51.56%
# Index: 929 & process: 51.61%
# Index: 930 & process: 51.67%
# Index: 931 & process: 51.72%
# Index: 932 & process: 51.78%
# Index: 933 & process: 51.83%
# Index: 934 & process: 51.89%
# Index: 935 & process: 51.94%
# Index: 936 & process: 52.00%
# Index: 937 & process: 52.06%
# Index: 938 & process: 52.11%
# Index: 939 & process: 52.17%
# Index: 940 & process: 52.22%
# Index: 941 & process: 52.28%
# Index: 942 & process: 52.33%
# Index: 943 & process: 52.39%
# Index: 944 & process: 52.44%
# Index: 945 & process: 52.50%
# Index: 946 & process: 52.56%
# Index: 947 & process: 52.61%
# Index: 948 & process: 52.67%
# Index: 949 & process: 52.72%
# Index: 950 & process: 52.78%
# Index: 951 & process: 52.83%
# Index: 952 & process: 52.89%
# Index: 953 & process: 52.94%
# Index: 954 & process: 53.00%
# Index: 955 & process: 53.06%
# Index: 956 & process: 53.11%
# Index: 957 & process: 53.17%
# Index: 958 & process: 53.22%
# Index: 959 & process: 53.28%
# Index: 960 & process: 53.33%
# Index: 961 & process: 53.39%
# Index: 962 & process: 53.44%
# Index: 963 & process: 53.50%
# Index: 964 & process: 53.56%
# Index: 965 & process: 53.61%
# Index: 966 & process: 53.67%
# Index: 967 & process: 53.72%
# Index: 968 & process: 53.78%
# Index: 969 & process: 53.83%
# Index: 970 & process: 53.89%
# Index: 971 & process: 53.94%
# Index: 972 & process: 54.00%
# Index: 973 & process: 54.06%
# Index: 974 & process: 54.11%
# Index: 975 & process: 54.17%
# Index: 976 & process: 54.22%
# Index: 977 & process: 54.28%
# Index: 978 & process: 54.33%
# Index: 979 & process: 54.39%
# Index: 980 & process: 54.44%
# Index: 981 & process: 54.50%
# Index: 982 & process: 54.56%
# Index: 983 & process: 54.61%
# Index: 984 & process: 54.67%
# Index: 985 & process: 54.72%
# Index: 986 & process: 54.78%
# Index: 987 & process: 54.83%
# Index: 988 & process: 54.89%
# Index: 989 & process: 54.94%
# Index: 990 & process: 55.00%
# Index: 991 & process: 55.06%
# Index: 992 & process: 55.11%
# Index: 993 & process: 55.17%
# Index: 994 & process: 55.22%
# Index: 995 & process: 55.28%
# Index: 996 & process: 55.33%
# Index: 997 & process: 55.39%
# Index: 998 & process: 55.44%
# Index: 999 & process: 55.50%
# Index: 1000 & process: 55.56%
# Index: 1001 & process: 55.61%
# Index: 1002 & process: 55.67%
# Index: 1003 & process: 55.72%
# Index: 1004 & process: 55.78%
# Index: 1005 & process: 55.83%
# Index: 1006 & process: 55.89%
# Index: 1007 & process: 55.94%
# Index: 1008 & process: 56.00%
# Index: 1009 & process: 56.06%
# Index: 1010 & process: 56.11%
# Index: 1011 & process: 56.17%
# Index: 1012 & process: 56.22%
# Index: 1013 & process: 56.28%
# Index: 1014 & process: 56.33%
# Index: 1015 & process: 56.39%
# Index: 1016 & process: 56.44%
# Index: 1017 & process: 56.50%
# Index: 1018 & process: 56.56%
# Index: 1019 & process: 56.61%
# Index: 1020 & process: 56.67%
# Index: 1021 & process: 56.72%
# Index: 1022 & process: 56.78%
# Index: 1023 & process: 56.83%
# Index: 1024 & process: 56.89%
# Index: 1025 & process: 56.94%
# Index: 1026 & process: 57.00%
# Index: 1027 & process: 57.06%
# Index: 1028 & process: 57.11%
# Index: 1029 & process: 57.17%
# Index: 1030 & process: 57.22%
# Index: 1031 & process: 57.28%
# Index: 1032 & process: 57.33%
# Index: 1033 & process: 57.39%
# Index: 1034 & process: 57.44%
# Index: 1035 & process: 57.50%
# Index: 1036 & process: 57.56%
# Index: 1037 & process: 57.61%
# Index: 1038 & process: 57.67%
# Index: 1039 & process: 57.72%
# Index: 1040 & process: 57.78%
# Index: 1041 & process: 57.83%
# Index: 1042 & process: 57.89%
# Index: 1043 & process: 57.94%
# Index: 1044 & process: 58.00%
# Index: 1045 & process: 58.06%
# Index: 1046 & process: 58.11%
# Index: 1047 & process: 58.17%
# Index: 1048 & process: 58.22%
# Index: 1049 & process: 58.28%
# Index: 1050 & process: 58.33%
# Index: 1051 & process: 58.39%
# Index: 1052 & process: 58.44%
# Index: 1053 & process: 58.50%
# Index: 1054 & process: 58.56%
# Index: 1055 & process: 58.61%
# Index: 1056 & process: 58.67%
# Index: 1057 & process: 58.72%
# Index: 1058 & process: 58.78%
# Index: 1059 & process: 58.83%
# Index: 1060 & process: 58.89%
# Index: 1061 & process: 58.94%
# Index: 1062 & process: 59.00%
# Index: 1063 & process: 59.06%
# Index: 1064 & process: 59.11%
# Index: 1065 & process: 59.17%
# Index: 1066 & process: 59.22%
# Index: 1067 & process: 59.28%
# Index: 1068 & process: 59.33%
# Index: 1069 & process: 59.39%
# Index: 1070 & process: 59.44%
# Index: 1071 & process: 59.50%
# Index: 1072 & process: 59.56%
# Index: 1073 & process: 59.61%
# Index: 1074 & process: 59.67%
# Index: 1075 & process: 59.72%
# Index: 1076 & process: 59.78%
# Index: 1077 & process: 59.83%
# Index: 1078 & process: 59.89%
# Index: 1079 & process: 59.94%
# Index: 1080 & process: 60.00%
# Index: 1081 & process: 60.06%
# Index: 1082 & process: 60.11%
# Index: 1083 & process: 60.17%
# Index: 1084 & process: 60.22%
# Index: 1085 & process: 60.28%
# Index: 1086 & process: 60.33%
# Index: 1087 & process: 60.39%
# Index: 1088 & process: 60.44%
# Index: 1089 & process: 60.50%
# Index: 1090 & process: 60.56%
# Index: 1091 & process: 60.61%
# Index: 1092 & process: 60.67%
# Index: 1093 & process: 60.72%
# Index: 1094 & process: 60.78%
# Index: 1095 & process: 60.83%
# Index: 1096 & process: 60.89%
# Index: 1097 & process: 60.94%
# Index: 1098 & process: 61.00%
# Index: 1099 & process: 61.06%
# Index: 1100 & process: 61.11%
# Index: 1101 & process: 61.17%
# Index: 1102 & process: 61.22%
# Index: 1103 & process: 61.28%
# Index: 1104 & process: 61.33%
# Index: 1105 & process: 61.39%
# Index: 1106 & process: 61.44%
# Index: 1107 & process: 61.50%
# Index: 1108 & process: 61.56%
# Index: 1109 & process: 61.61%
# Index: 1110 & process: 61.67%
# Index: 1111 & process: 61.72%
# Index: 1112 & process: 61.78%
# Index: 1113 & process: 61.83%
# Index: 1114 & process: 61.89%
# Index: 1115 & process: 61.94%
# Index: 1116 & process: 62.00%
# Index: 1117 & process: 62.06%
# Index: 1118 & process: 62.11%
# Index: 1119 & process: 62.17%
# Index: 1120 & process: 62.22%
# Index: 1121 & process: 62.28%
# Index: 1122 & process: 62.33%
# Index: 1123 & process: 62.39%
# Index: 1124 & process: 62.44%
# Index: 1125 & process: 62.50%
# Index: 1126 & process: 62.56%
# Index: 1127 & process: 62.61%
# Index: 1128 & process: 62.67%
# Index: 1129 & process: 62.72%
# Index: 1130 & process: 62.78%
# Index: 1131 & process: 62.83%
# Index: 1132 & process: 62.89%
# Index: 1133 & process: 62.94%
# Index: 1134 & process: 63.00%
# Index: 1135 & process: 63.06%
# Index: 1136 & process: 63.11%
# Index: 1137 & process: 63.17%
# Index: 1138 & process: 63.22%
# Index: 1139 & process: 63.28%
# Index: 1140 & process: 63.33%
# Index: 1141 & process: 63.39%
# Index: 1142 & process: 63.44%
# Index: 1143 & process: 63.50%
# Index: 1144 & process: 63.56%
# Index: 1145 & process: 63.61%
# Index: 1146 & process: 63.67%
# Index: 1147 & process: 63.72%
# Index: 1148 & process: 63.78%
# Index: 1149 & process: 63.83%
# Index: 1150 & process: 63.89%
# Index: 1151 & process: 63.94%
# Index: 1152 & process: 64.00%
# Index: 1153 & process: 64.06%
# Index: 1154 & process: 64.11%
# Index: 1155 & process: 64.17%
# Index: 1156 & process: 64.22%
# Index: 1157 & process: 64.28%
# Index: 1158 & process: 64.33%
# Index: 1159 & process: 64.39%
# Index: 1160 & process: 64.44%
# Index: 1161 & process: 64.50%
# Index: 1162 & process: 64.56%
# Index: 1163 & process: 64.61%
# Index: 1164 & process: 64.67%
# Index: 1165 & process: 64.72%
# Index: 1166 & process: 64.78%
# Index: 1167 & process: 64.83%
# Index: 1168 & process: 64.89%
# Index: 1169 & process: 64.94%
# Index: 1170 & process: 65.00%
# Index: 1171 & process: 65.06%
# Index: 1172 & process: 65.11%
# Index: 1173 & process: 65.17%
# Index: 1174 & process: 65.22%
# Index: 1175 & process: 65.28%
# Index: 1176 & process: 65.33%
# Index: 1177 & process: 65.39%
# Index: 1178 & process: 65.44%
# Index: 1179 & process: 65.50%
# Index: 1180 & process: 65.56%
# Index: 1181 & process: 65.61%
# Index: 1182 & process: 65.67%
# Index: 1183 & process: 65.72%
# Index: 1184 & process: 65.78%
# Index: 1185 & process: 65.83%
# Index: 1186 & process: 65.89%
# Index: 1187 & process: 65.94%
# Index: 1188 & process: 66.00%
# Index: 1189 & process: 66.06%
# Index: 1190 & process: 66.11%
# Index: 1191 & process: 66.17%
# Index: 1192 & process: 66.22%
# Index: 1193 & process: 66.28%
# Index: 1194 & process: 66.33%
# Index: 1195 & process: 66.39%
# Index: 1196 & process: 66.44%
# Index: 1197 & process: 66.50%
# Index: 1198 & process: 66.56%
# Index: 1199 & process: 66.61%
# Index: 1200 & process: 66.67%
# Index: 1201 & process: 66.72%
# Index: 1202 & process: 66.78%
# Index: 1203 & process: 66.83%
# Index: 1204 & process: 66.89%
# Index: 1205 & process: 66.94%
# Index: 1206 & process: 67.00%
# Index: 1207 & process: 67.06%
# Index: 1208 & process: 67.11%
# Index: 1209 & process: 67.17%
# Index: 1210 & process: 67.22%
# Index: 1211 & process: 67.28%
# Index: 1212 & process: 67.33%
# Index: 1213 & process: 67.39%
# Index: 1214 & process: 67.44%
# Index: 1215 & process: 67.50%
# Index: 1216 & process: 67.56%
# Index: 1217 & process: 67.61%
# Index: 1218 & process: 67.67%
# Index: 1219 & process: 67.72%
# Index: 1220 & process: 67.78%
# Index: 1221 & process: 67.83%
# Index: 1222 & process: 67.89%
# Index: 1223 & process: 67.94%
# Index: 1224 & process: 68.00%
# Index: 1225 & process: 68.06%
# Index: 1226 & process: 68.11%
# Index: 1227 & process: 68.17%
# Index: 1228 & process: 68.22%
# Index: 1229 & process: 68.28%
# Index: 1230 & process: 68.33%
# Index: 1231 & process: 68.39%
# Index: 1232 & process: 68.44%
# Index: 1233 & process: 68.50%
# Index: 1234 & process: 68.56%
# Index: 1235 & process: 68.61%
# Index: 1236 & process: 68.67%
# Index: 1237 & process: 68.72%
# Index: 1238 & process: 68.78%
# Index: 1239 & process: 68.83%
# Index: 1240 & process: 68.89%
# Index: 1241 & process: 68.94%
# Index: 1242 & process: 69.00%
# Index: 1243 & process: 69.06%
# Index: 1244 & process: 69.11%
# Index: 1245 & process: 69.17%
# Index: 1246 & process: 69.22%
# Index: 1247 & process: 69.28%
# Index: 1248 & process: 69.33%
# Index: 1249 & process: 69.39%
# Index: 1250 & process: 69.44%
# Index: 1251 & process: 69.50%
# Index: 1252 & process: 69.56%
# Index: 1253 & process: 69.61%
# Index: 1254 & process: 69.67%
# Index: 1255 & process: 69.72%
# Index: 1256 & process: 69.78%
# Index: 1257 & process: 69.83%
# Index: 1258 & process: 69.89%
# Index: 1259 & process: 69.94%
# Index: 1260 & process: 70.00%
# Index: 1261 & process: 70.06%
# Index: 1262 & process: 70.11%
# Index: 1263 & process: 70.17%
# Index: 1264 & process: 70.22%
# Index: 1265 & process: 70.28%
# Index: 1266 & process: 70.33%
# Index: 1267 & process: 70.39%
# Index: 1268 & process: 70.44%
# Index: 1269 & process: 70.50%
# Index: 1270 & process: 70.56%
# Index: 1271 & process: 70.61%
# Index: 1272 & process: 70.67%
# Index: 1273 & process: 70.72%
# Index: 1274 & process: 70.78%
# Index: 1275 & process: 70.83%
# Index: 1276 & process: 70.89%
# Index: 1277 & process: 70.94%
# Index: 1278 & process: 71.00%
# Index: 1279 & process: 71.06%
# Index: 1280 & process: 71.11%
# Index: 1281 & process: 71.17%
# Index: 1282 & process: 71.22%
# Index: 1283 & process: 71.28%
# Index: 1284 & process: 71.33%
# Index: 1285 & process: 71.39%
# Index: 1286 & process: 71.44%
# Index: 1287 & process: 71.50%
# Index: 1288 & process: 71.56%
# Index: 1289 & process: 71.61%
# Index: 1290 & process: 71.67%
# Index: 1291 & process: 71.72%
# Index: 1292 & process: 71.78%
# Index: 1293 & process: 71.83%
# Index: 1294 & process: 71.89%
# Index: 1295 & process: 71.94%
# Index: 1296 & process: 72.00%
# Index: 1297 & process: 72.06%
# Index: 1298 & process: 72.11%
# Index: 1299 & process: 72.17%
# Index: 1300 & process: 72.22%
# Index: 1301 & process: 72.28%
# Index: 1302 & process: 72.33%
# Index: 1303 & process: 72.39%
# Index: 1304 & process: 72.44%
# Index: 1305 & process: 72.50%
# Index: 1306 & process: 72.56%
# Index: 1307 & process: 72.61%
# Index: 1308 & process: 72.67%
# Index: 1309 & process: 72.72%
# Index: 1310 & process: 72.78%
# Index: 1311 & process: 72.83%
# Index: 1312 & process: 72.89%
# Index: 1313 & process: 72.94%
# Index: 1314 & process: 73.00%
# Index: 1315 & process: 73.06%
# Index: 1316 & process: 73.11%
# Index: 1317 & process: 73.17%
# Index: 1318 & process: 73.22%
# Index: 1319 & process: 73.28%
# Index: 1320 & process: 73.33%
# Index: 1321 & process: 73.39%
# Index: 1322 & process: 73.44%
# Index: 1323 & process: 73.50%
# Index: 1324 & process: 73.56%
# Index: 1325 & process: 73.61%
# Index: 1326 & process: 73.67%
# Index: 1327 & process: 73.72%
# Index: 1328 & process: 73.78%
# Index: 1329 & process: 73.83%
# Index: 1330 & process: 73.89%
# Index: 1331 & process: 73.94%
# Index: 1332 & process: 74.00%
# Index: 1333 & process: 74.06%
# Index: 1334 & process: 74.11%
# Index: 1335 & process: 74.17%
# Index: 1336 & process: 74.22%
# Index: 1337 & process: 74.28%
# Index: 1338 & process: 74.33%
# Index: 1339 & process: 74.39%
# Index: 1340 & process: 74.44%
# Index: 1341 & process: 74.50%
# Index: 1342 & process: 74.56%
# Index: 1343 & process: 74.61%
# Index: 1344 & process: 74.67%
# Index: 1345 & process: 74.72%
# Index: 1346 & process: 74.78%
# Index: 1347 & process: 74.83%
# Index: 1348 & process: 74.89%
# Index: 1349 & process: 74.94%
# Index: 1350 & process: 75.00%
# Index: 1351 & process: 75.06%
# Index: 1352 & process: 75.11%
# Index: 1353 & process: 75.17%
# Index: 1354 & process: 75.22%
# Index: 1355 & process: 75.28%
# Index: 1356 & process: 75.33%
# Index: 1357 & process: 75.39%
# Index: 1358 & process: 75.44%
# Index: 1359 & process: 75.50%
# Index: 1360 & process: 75.56%
# Index: 1361 & process: 75.61%
# Index: 1362 & process: 75.67%
# Index: 1363 & process: 75.72%
# Index: 1364 & process: 75.78%
# Index: 1365 & process: 75.83%
# Index: 1366 & process: 75.89%
# Index: 1367 & process: 75.94%
# Index: 1368 & process: 76.00%
# Index: 1369 & process: 76.06%
# Index: 1370 & process: 76.11%
# Index: 1371 & process: 76.17%
# Index: 1372 & process: 76.22%
# Index: 1373 & process: 76.28%
# Index: 1374 & process: 76.33%
# Index: 1375 & process: 76.39%
# Index: 1376 & process: 76.44%
# Index: 1377 & process: 76.50%
# Index: 1378 & process: 76.56%
# Index: 1379 & process: 76.61%
# Index: 1380 & process: 76.67%
# Index: 1381 & process: 76.72%
# Index: 1382 & process: 76.78%
# Index: 1383 & process: 76.83%
# Index: 1384 & process: 76.89%
# Index: 1385 & process: 76.94%
# Index: 1386 & process: 77.00%
# Index: 1387 & process: 77.06%
# Index: 1388 & process: 77.11%
# Index: 1389 & process: 77.17%
# Index: 1390 & process: 77.22%
# Index: 1391 & process: 77.28%
# Index: 1392 & process: 77.33%
# Index: 1393 & process: 77.39%
# Index: 1394 & process: 77.44%
# Index: 1395 & process: 77.50%
# Index: 1396 & process: 77.56%
# Index: 1397 & process: 77.61%
# Index: 1398 & process: 77.67%
# Index: 1399 & process: 77.72%
# Index: 1400 & process: 77.78%
# Index: 1401 & process: 77.83%
# Index: 1402 & process: 77.89%
# Index: 1403 & process: 77.94%
# Index: 1404 & process: 78.00%
# Index: 1405 & process: 78.06%
# Index: 1406 & process: 78.11%
# Index: 1407 & process: 78.17%
# Index: 1408 & process: 78.22%
# Index: 1409 & process: 78.28%
# Index: 1410 & process: 78.33%
# Index: 1411 & process: 78.39%
# Index: 1412 & process: 78.44%
# Index: 1413 & process: 78.50%
# Index: 1414 & process: 78.56%
# Index: 1415 & process: 78.61%
# Index: 1416 & process: 78.67%
# Index: 1417 & process: 78.72%
# Index: 1418 & process: 78.78%
# Index: 1419 & process: 78.83%
# Index: 1420 & process: 78.89%
# Index: 1421 & process: 78.94%
# Index: 1422 & process: 79.00%
# Index: 1423 & process: 79.06%
# Index: 1424 & process: 79.11%
# Index: 1425 & process: 79.17%
# Index: 1426 & process: 79.22%
# Index: 1427 & process: 79.28%
# Index: 1428 & process: 79.33%
# Index: 1429 & process: 79.39%
# Index: 1430 & process: 79.44%
# Index: 1431 & process: 79.50%
# Index: 1432 & process: 79.56%
# Index: 1433 & process: 79.61%
# Index: 1434 & process: 79.67%
# Index: 1435 & process: 79.72%
# Index: 1436 & process: 79.78%
# Index: 1437 & process: 79.83%
# Index: 1438 & process: 79.89%
# Index: 1439 & process: 79.94%
# Index: 1440 & process: 80.00%
# Index: 1441 & process: 80.06%
# Index: 1442 & process: 80.11%
# Index: 1443 & process: 80.17%
# Index: 1444 & process: 80.22%
# Index: 1445 & process: 80.28%
# Index: 1446 & process: 80.33%
# Index: 1447 & process: 80.39%
# Index: 1448 & process: 80.44%
# Index: 1449 & process: 80.50%
# Index: 1450 & process: 80.56%
# Index: 1451 & process: 80.61%
# Index: 1452 & process: 80.67%
# Index: 1453 & process: 80.72%
# Index: 1454 & process: 80.78%
# Index: 1455 & process: 80.83%
# Index: 1456 & process: 80.89%
# Index: 1457 & process: 80.94%
# Index: 1458 & process: 81.00%
# Index: 1459 & process: 81.06%
# Index: 1460 & process: 81.11%
# Index: 1461 & process: 81.17%
# Index: 1462 & process: 81.22%
# Index: 1463 & process: 81.28%
# Index: 1464 & process: 81.33%
# Index: 1465 & process: 81.39%
# Index: 1466 & process: 81.44%
# Index: 1467 & process: 81.50%
# Index: 1468 & process: 81.56%
# Index: 1469 & process: 81.61%
# Index: 1470 & process: 81.67%
# Index: 1471 & process: 81.72%
# Index: 1472 & process: 81.78%
# Index: 1473 & process: 81.83%
# Index: 1474 & process: 81.89%
# Index: 1475 & process: 81.94%
# Index: 1476 & process: 82.00%
# Index: 1477 & process: 82.06%
# Index: 1478 & process: 82.11%
# Index: 1479 & process: 82.17%
# Index: 1480 & process: 82.22%
# Index: 1481 & process: 82.28%
# Index: 1482 & process: 82.33%
# Index: 1483 & process: 82.39%
# Index: 1484 & process: 82.44%
# Index: 1485 & process: 82.50%
# Index: 1486 & process: 82.56%
# Index: 1487 & process: 82.61%
# Index: 1488 & process: 82.67%
# Index: 1489 & process: 82.72%
# Index: 1490 & process: 82.78%
# Index: 1491 & process: 82.83%
# Index: 1492 & process: 82.89%
# Index: 1493 & process: 82.94%
# Index: 1494 & process: 83.00%
# Index: 1495 & process: 83.06%
# Index: 1496 & process: 83.11%
# Index: 1497 & process: 83.17%
# Index: 1498 & process: 83.22%
# Index: 1499 & process: 83.28%
# Index: 1500 & process: 83.33%
# Index: 1501 & process: 83.39%
# Index: 1502 & process: 83.44%
# Index: 1503 & process: 83.50%
# Index: 1504 & process: 83.56%
# Index: 1505 & process: 83.61%
# Index: 1506 & process: 83.67%
# Index: 1507 & process: 83.72%
# Index: 1508 & process: 83.78%
# Index: 1509 & process: 83.83%
# Index: 1510 & process: 83.89%
# Index: 1511 & process: 83.94%
# Index: 1512 & process: 84.00%
# Index: 1513 & process: 84.06%
# Index: 1514 & process: 84.11%
# Index: 1515 & process: 84.17%
# Index: 1516 & process: 84.22%
# Index: 1517 & process: 84.28%
# Index: 1518 & process: 84.33%
# Index: 1519 & process: 84.39%
# Index: 1520 & process: 84.44%
# Index: 1521 & process: 84.50%
# Index: 1522 & process: 84.56%
# Index: 1523 & process: 84.61%
# Index: 1524 & process: 84.67%
# Index: 1525 & process: 84.72%
# Index: 1526 & process: 84.78%
# Index: 1527 & process: 84.83%
# Index: 1528 & process: 84.89%
# Index: 1529 & process: 84.94%
# Index: 1530 & process: 85.00%
# Index: 1531 & process: 85.06%
# Index: 1532 & process: 85.11%
# Index: 1533 & process: 85.17%
# Index: 1534 & process: 85.22%
# Index: 1535 & process: 85.28%
# Index: 1536 & process: 85.33%
# Index: 1537 & process: 85.39%
# Index: 1538 & process: 85.44%
# Index: 1539 & process: 85.50%
# Index: 1540 & process: 85.56%
# Index: 1541 & process: 85.61%
# Index: 1542 & process: 85.67%
# Index: 1543 & process: 85.72%
# Index: 1544 & process: 85.78%
# Index: 1545 & process: 85.83%
# Index: 1546 & process: 85.89%
# Index: 1547 & process: 85.94%
# Index: 1548 & process: 86.00%
# Index: 1549 & process: 86.06%
# Index: 1550 & process: 86.11%
# Index: 1551 & process: 86.17%
# Index: 1552 & process: 86.22%
# Index: 1553 & process: 86.28%
# Index: 1554 & process: 86.33%
# Index: 1555 & process: 86.39%
# Index: 1556 & process: 86.44%
# Index: 1557 & process: 86.50%
# Index: 1558 & process: 86.56%
# Index: 1559 & process: 86.61%
# Index: 1560 & process: 86.67%
# Index: 1561 & process: 86.72%
# Index: 1562 & process: 86.78%
# Index: 1563 & process: 86.83%
# Index: 1564 & process: 86.89%
# Index: 1565 & process: 86.94%
# Index: 1566 & process: 87.00%
# Index: 1567 & process: 87.06%
# Index: 1568 & process: 87.11%
# Index: 1569 & process: 87.17%
# Index: 1570 & process: 87.22%
# Index: 1571 & process: 87.28%
# Index: 1572 & process: 87.33%
# Index: 1573 & process: 87.39%
# Index: 1574 & process: 87.44%
# Index: 1575 & process: 87.50%
# Index: 1576 & process: 87.56%
# Index: 1577 & process: 87.61%
# Index: 1578 & process: 87.67%
# Index: 1579 & process: 87.72%
# Index: 1580 & process: 87.78%
# Index: 1581 & process: 87.83%
# Index: 1582 & process: 87.89%
# Index: 1583 & process: 87.94%
# Index: 1584 & process: 88.00%
# Index: 1585 & process: 88.06%
# Index: 1586 & process: 88.11%
# Index: 1587 & process: 88.17%
# Index: 1588 & process: 88.22%
# Index: 1589 & process: 88.28%
# Index: 1590 & process: 88.33%
# Index: 1591 & process: 88.39%
# Index: 1592 & process: 88.44%
# Index: 1593 & process: 88.50%
# Index: 1594 & process: 88.56%
# Index: 1595 & process: 88.61%
# Index: 1596 & process: 88.67%
# Index: 1597 & process: 88.72%
# Index: 1598 & process: 88.78%
# Index: 1599 & process: 88.83%
# Index: 1600 & process: 88.89%
# Index: 1601 & process: 88.94%
# Index: 1602 & process: 89.00%
# Index: 1603 & process: 89.06%
# Index: 1604 & process: 89.11%
# Index: 1605 & process: 89.17%
# Index: 1606 & process: 89.22%
# Index: 1607 & process: 89.28%
# Index: 1608 & process: 89.33%
# Index: 1609 & process: 89.39%
# Index: 1610 & process: 89.44%
# Index: 1611 & process: 89.50%
# Index: 1612 & process: 89.56%
# Index: 1613 & process: 89.61%
# Index: 1614 & process: 89.67%
# Index: 1615 & process: 89.72%
# Index: 1616 & process: 89.78%
# Index: 1617 & process: 89.83%
# Index: 1618 & process: 89.89%
# Index: 1619 & process: 89.94%
# Index: 1620 & process: 90.00%
# Index: 1621 & process: 90.06%
# Index: 1622 & process: 90.11%
# Index: 1623 & process: 90.17%
# Index: 1624 & process: 90.22%
# Index: 1625 & process: 90.28%
# Index: 1626 & process: 90.33%
# Index: 1627 & process: 90.39%
# Index: 1628 & process: 90.44%
# Index: 1629 & process: 90.50%
# Index: 1630 & process: 90.56%
# Index: 1631 & process: 90.61%
# Index: 1632 & process: 90.67%
# Index: 1633 & process: 90.72%
# Index: 1634 & process: 90.78%
# Index: 1635 & process: 90.83%
# Index: 1636 & process: 90.89%
# Index: 1637 & process: 90.94%
# Index: 1638 & process: 91.00%
# Index: 1639 & process: 91.06%
# Index: 1640 & process: 91.11%
# Index: 1641 & process: 91.17%
# Index: 1642 & process: 91.22%
# Index: 1643 & process: 91.28%
# Index: 1644 & process: 91.33%
# Index: 1645 & process: 91.39%
# Index: 1646 & process: 91.44%
# Index: 1647 & process: 91.50%
# Index: 1648 & process: 91.56%
# Index: 1649 & process: 91.61%
# Index: 1650 & process: 91.67%
# Index: 1651 & process: 91.72%
# Index: 1652 & process: 91.78%
# Index: 1653 & process: 91.83%
# Index: 1654 & process: 91.89%
# Index: 1655 & process: 91.94%
# Index: 1656 & process: 92.00%
# Index: 1657 & process: 92.06%
# Index: 1658 & process: 92.11%
# Index: 1659 & process: 92.17%
# Index: 1660 & process: 92.22%
# Index: 1661 & process: 92.28%
# Index: 1662 & process: 92.33%
# Index: 1663 & process: 92.39%
# Index: 1664 & process: 92.44%
# Index: 1665 & process: 92.50%
# Index: 1666 & process: 92.56%
# Index: 1667 & process: 92.61%
# Index: 1668 & process: 92.67%
# Index: 1669 & process: 92.72%
# Index: 1670 & process: 92.78%
# Index: 1671 & process: 92.83%
# Index: 1672 & process: 92.89%
# Index: 1673 & process: 92.94%
# Index: 1674 & process: 93.00%
# Index: 1675 & process: 93.06%
# Index: 1676 & process: 93.11%
# Index: 1677 & process: 93.17%
# Index: 1678 & process: 93.22%
# Index: 1679 & process: 93.28%
# Index: 1680 & process: 93.33%
# Index: 1681 & process: 93.39%
# Index: 1682 & process: 93.44%
# Index: 1683 & process: 93.50%
# Index: 1684 & process: 93.56%
# Index: 1685 & process: 93.61%
# Index: 1686 & process: 93.67%
# Index: 1687 & process: 93.72%
# Index: 1688 & process: 93.78%
# Index: 1689 & process: 93.83%
# Index: 1690 & process: 93.89%
# Index: 1691 & process: 93.94%
# Index: 1692 & process: 94.00%
# Index: 1693 & process: 94.06%
# Index: 1694 & process: 94.11%
# Index: 1695 & process: 94.17%
# Index: 1696 & process: 94.22%
# Index: 1697 & process: 94.28%
# Index: 1698 & process: 94.33%
# Index: 1699 & process: 94.39%
# Index: 1700 & process: 94.44%
# Index: 1701 & process: 94.50%
# Index: 1702 & process: 94.56%
# Index: 1703 & process: 94.61%
# Index: 1704 & process: 94.67%
# Index: 1705 & process: 94.72%
# Index: 1706 & process: 94.78%
# Index: 1707 & process: 94.83%
# Index: 1708 & process: 94.89%
# Index: 1709 & process: 94.94%
# Index: 1710 & process: 95.00%
# Index: 1711 & process: 95.06%
# Index: 1712 & process: 95.11%
# Index: 1713 & process: 95.17%
# Index: 1714 & process: 95.22%
# Index: 1715 & process: 95.28%
# Index: 1716 & process: 95.33%
# Index: 1717 & process: 95.39%
# Index: 1718 & process: 95.44%
# Index: 1719 & process: 95.50%
# Index: 1720 & process: 95.56%
# Index: 1721 & process: 95.61%
# Index: 1722 & process: 95.67%
# Index: 1723 & process: 95.72%
# Index: 1724 & process: 95.78%
# Index: 1725 & process: 95.83%
# Index: 1726 & process: 95.89%
# Index: 1727 & process: 95.94%
# Index: 1728 & process: 96.00%
# Index: 1729 & process: 96.06%
# Index: 1730 & process: 96.11%
# Index: 1731 & process: 96.17%
# Index: 1732 & process: 96.22%
# Index: 1733 & process: 96.28%
# Index: 1734 & process: 96.33%
# Index: 1735 & process: 96.39%
# Index: 1736 & process: 96.44%
# Index: 1737 & process: 96.50%
# Index: 1738 & process: 96.56%
# Index: 1739 & process: 96.61%
# Index: 1740 & process: 96.67%
# Index: 1741 & process: 96.72%
# Index: 1742 & process: 96.78%
# Index: 1743 & process: 96.83%
# Index: 1744 & process: 96.89%
# Index: 1745 & process: 96.94%
# Index: 1746 & process: 97.00%
# Index: 1747 & process: 97.06%
# Index: 1748 & process: 97.11%
# Index: 1749 & process: 97.17%
# Index: 1750 & process: 97.22%
# Index: 1751 & process: 97.28%
# Index: 1752 & process: 97.33%
# Index: 1753 & process: 97.39%
# Index: 1754 & process: 97.44%
# Index: 1755 & process: 97.50%
# Index: 1756 & process: 97.56%
# Index: 1757 & process: 97.61%
# Index: 1758 & process: 97.67%
# Index: 1759 & process: 97.72%
# Index: 1760 & process: 97.78%
# Index: 1761 & process: 97.83%
# Index: 1762 & process: 97.89%
# Index: 1763 & process: 97.94%
# Index: 1764 & process: 98.00%
# Index: 1765 & process: 98.06%
# Index: 1766 & process: 98.11%
# Index: 1767 & process: 98.17%
# Index: 1768 & process: 98.22%
# Index: 1769 & process: 98.28%
# Index: 1770 & process: 98.33%
# Index: 1771 & process: 98.39%
# Index: 1772 & process: 98.44%
# Index: 1773 & process: 98.50%
# Index: 1774 & process: 98.56%
# Index: 1775 & process: 98.61%
# Index: 1776 & process: 98.67%
# Index: 1777 & process: 98.72%
# Index: 1778 & process: 98.78%
# Index: 1779 & process: 98.83%
# Index: 1780 & process: 98.89%
# Index: 1781 & process: 98.94%
# Index: 1782 & process: 99.00%
# Index: 1783 & process: 99.06%
# Index: 1784 & process: 99.11%
# Index: 1785 & process: 99.17%
# Index: 1786 & process: 99.22%
# Index: 1787 & process: 99.28%
# Index: 1788 & process: 99.33%
# Index: 1789 & process: 99.39%
# Index: 1790 & process: 99.44%
# Index: 1791 & process: 99.50%
# Index: 1792 & process: 99.56%
# Index: 1793 & process: 99.61%
# Index: 1794 & process: 99.67%
# Index: 1795 & process: 99.72%
# Index: 1796 & process: 99.78%
# Index: 1797 & process: 99.83%
# Index: 1798 & process: 99.89%
# Index: 1799 & process: 99.94%
# Index: 1800 & process: 100.00%

# %%
def remove_eng(s):
    res = ''
    for char in s:
        if char.isdigit() or char == '_':
            res += char
    return res

def time_extract(f: str) -> str:
    day = remove_eng('_'.join(f.split(' ')[0].split('_')[1:]))
    time = f.split(' ')[1] + ' ' + f.split(' ')[-1].split('.')[0]
    return day + ' ' + time

def check_matching(data, center, err):
    if abs(center[0]-data['ra'].mean()) >= err:
        return True
    elif abs(center[1]-data['dec'].mean()) >= err:
        return True
    else:
        return False

file_ls = os.listdir(data_path)
time_ls = []

for filename in file_ls:
    try:
        t = time_extract(filename)
    except:
        raise Exception(filename)
    time_ls.append(t)

file_df = pd.DataFrame({
    'filename': file_ls,
    'time': time_ls,
})

file_df.time = pd.to_datetime(file_df.time, format='%m_%d_%Y %I_%M_%S %p')
file_df = file_df.sort_values(by='time')
file_df = file_df.reset_index(drop=True)
file_df.index = file_df.index + 1

gal_df_ls = []

for idx, row in file_df.iterrows():
    df = pd.read_csv(data_path + row['filename'], header=1)
    center = (cls_info.loc[idx+1000, 'ra'], cls_info.loc[idx+1000, 'dec'])    
    gal_df_ls.append(df)
    if check_matching(df, center, 0.7):
        print(idx)
        print(df.ra.mean(), df.dec.mean())
        print(center)
        break
    gal_df_ls.append(df)
# Out:
# 202
# 174.791019940972 55.6667351395397
# (192.28152, -1.7848679)

# %%
def get_missing_data(driver, cls_info, index):
    cls1 = cls_info.loc[index, :]
    ra = cls1['ra']
    dec = cls1['dec']
    dist = cls1['comv_dist']
    r200 = cls1['r_200']
    v_r = cls1['v_rad']
    sigma = cls1['sigma_200']
    theta = multiple * np.arcsin(r200 / dist) * (180 / np.pi) * 60
    print('Index: {0} & process: {1:.2f}%'.format(idx, 100 * idx/N))
    
    z_upper = redshift(v_r + multiple * sigma)
    z_lower = redshift(v_r - multiple * sigma)
    
    query = make_query(ra, dec, theta, r200, dist, z_upper, z_lower)
    get_csv(driver, query)

# %%
get_missing_data(driver, cls_info, 1703)
# Out:
# Index: 1800 & process: 100.00%
